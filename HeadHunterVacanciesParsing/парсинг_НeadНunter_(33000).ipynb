# %%
import requests
import csv
import time
from datetime import datetime, timedelta

API_URL = "https://api.hh.kz/vacancies"

date_from = datetime.today() - timedelta(days=30)
date_to = datetime.today()

regions = [159, 40, 37, 160]

csv_file = "hh_vacancies_Zaibal_MAIN.csv"
csv_columns = [
    "id", "title", "description", "requirements", "conditions", "locations",
    "postedDate", "employeeId", "createdAt", "updatedAt", "key_skills", "companyId",
    "companyName", "companyDescription", "contactInfo", "salary_from", "salary_to",
    "salary_currency", "salary_gross"
]

with open(csv_file, "w", newline="", encoding="utf-8") as file:
    writer = csv.DictWriter(file, fieldnames=csv_columns)
    writer.writeheader()

    total_vacancies = 0

    for region in regions:
        for days_ago in range(0, 30, 5):
            start_date = (date_from + timedelta(days=days_ago)).strftime("%Y-%m-%d")
            end_date = (date_from + timedelta(days=days_ago + 5)).strftime("%Y-%m-%d")

            params = {
                "area": region,
                "per_page": 100,
                "page": 0,
                "date_from": start_date,
                "date_to": end_date,
            }

            while True:
                response = requests.get(API_URL, params=params)
                data = response.json()

                if "items" not in data or not data["items"]:
                    break

                for vacancy in data["items"]:
                    vacancy_url = f"{API_URL}/{vacancy['id']}"
                    vacancy_details = requests.get(vacancy_url).json()

                    key_skills = ", ".join([skill.get("name", "") for skill in vacancy_details.get("key_skills", [])])

                    company_id = vacancy.get("employer", {}).get("id", "")
                    company_name = vacancy.get("employer", {}).get("name", "")
                    company_description = vacancy_details.get("employer", {}).get("description", "Нет описания")

                    contact_info = vacancy_details.get("contacts", {})
                    contact_info_str = ", ".join(f"{key}: {value}" for key, value in contact_info.items()) if contact_info else ""

                    vacancy_data = {
                        "id": vacancy.get("id"),
                        "title": vacancy.get("name"),
                        "description": vacancy.get("snippet", {}).get("responsibility", ""),
                        "requirements": vacancy.get("snippet", {}).get("requirement", ""),
                        "conditions": vacancy.get("employment", {}).get("name", ""),
                        "locations": vacancy.get("area", {}).get("name", ""),
                        "postedDate": vacancy.get("published_at", ""),
                        "employeeId": company_id,
                        "createdAt": vacancy_details.get("created_at", ""),
                        "updatedAt": vacancy_details.get("updated_at", ""),
                        "key_skills": key_skills,
                        "companyId": company_id,
                        "companyName": company_name,
                        "companyDescription": company_description,
                        "contactInfo": contact_info_str,
                        "salary_from": vacancy.get("salary", {}).get("from", "") if vacancy.get("salary") else "",
                        "salary_to": vacancy.get("salary", {}).get("to", "") if vacancy.get("salary") else "",
                        "salary_currency": vacancy.get("salary", {}).get("currency", "") if vacancy.get("salary") else "",
                        "salary_gross": vacancy.get("salary", {}).get("gross", "") if vacancy.get("salary") else ""
                    }

                    writer.writerow(vacancy_data)

                total_vacancies += len(data["items"])
                print(f"🔹 Скачано {total_vacancies} вакансий...")

                params["page"] += 1
                if params["page"] >= data.get("pages", 1):
                    break

                time.sleep(1)

print(f"✅ Вакансии сохранены в {csv_file} ({total_vacancies} шт.)")
# Out:
# 🔹 Скачано 100 вакансий...
# 🔹 Скачано 200 вакансий...
# 🔹 Скачано 300 вакансий...
# 🔹 Скачано 400 вакансий...
# 🔹 Скачано 500 вакансий...
# 🔹 Скачано 600 вакансий...
# 🔹 Скачано 700 вакансий...
# 🔹 Скачано 800 вакансий...
# 🔹 Скачано 900 вакансий...
# 🔹 Скачано 1000 вакансий...
# 🔹 Скачано 1100 вакансий...
# 🔹 Скачано 1200 вакансий...
# 🔹 Скачано 1300 вакансий...
# 🔹 Скачано 1390 вакансий...
# 🔹 Скачано 1490 вакансий...
# 🔹 Скачано 1590 вакансий...
# 🔹 Скачано 1690 вакансий...
# 🔹 Скачано 1790 вакансий...
# 🔹 Скачано 1890 вакансий...
# 🔹 Скачано 1990 вакансий...
# 🔹 Скачано 2090 вакансий...
# 🔹 Скачано 2190 вакансий...
# 🔹 Скачано 2290 вакансий...
# 🔹 Скачано 2390 вакансий...
# 🔹 Скачано 2490 вакансий...
# 🔹 Скачано 2590 вакансий...
# 🔹 Скачано 2690 вакансий...
# 🔹 Скачано 2699 вакансий...
# 🔹 Скачано 2799 вакансий...
# 🔹 Скачано 2899 вакансий...
# 🔹 Скачано 2999 вакансий...
# 🔹 Скачано 3099 вакансий...
# 🔹 Скачано 3199 вакансий...
# 🔹 Скачано 3299 вакансий...
# 🔹 Скачано 3399 вакансий...
# 🔹 Скачано 3499 вакансий...
# 🔹 Скачано 3599 вакансий...
# 🔹 Скачано 3699 вакансий...
# 🔹 Скачано 3799 вакансий...
# 🔹 Скачано 3899 вакансий...
# 🔹 Скачано 3999 вакансий...
# 🔹 Скачано 4014 вакансий...
# 🔹 Скачано 4114 вакансий...
# 🔹 Скачано 4214 вакансий...
# 🔹 Скачано 4314 вакансий...
# 🔹 Скачано 4414 вакансий...
# 🔹 Скачано 4514 вакансий...
# 🔹 Скачано 4614 вакансий...
# 🔹 Скачано 4714 вакансий...
# 🔹 Скачано 4814 вакансий...
# 🔹 Скачано 4914 вакансий...
# 🔹 Скачано 5014 вакансий...
# 🔹 Скачано 5114 вакансий...
# 🔹 Скачано 5214 вакансий...
# 🔹 Скачано 5314 вакансий...
# 🔹 Скачано 5414 вакансий...
# 🔹 Скачано 5514 вакансий...
# 🔹 Скачано 5544 вакансий...
# 🔹 Скачано 5644 вакансий...
# 🔹 Скачано 5744 вакансий...
# 🔹 Скачано 5844 вакансий...
# 🔹 Скачано 5944 вакансий...
# 🔹 Скачано 6044 вакансий...
# 🔹 Скачано 6144 вакансий...
# 🔹 Скачано 6244 вакансий...
# 🔹 Скачано 6344 вакансий...
# 🔹 Скачано 6444 вакансий...
# 🔹 Скачано 6544 вакансий...
# 🔹 Скачано 6644 вакансий...
# 🔹 Скачано 6744 вакансий...
# 🔹 Скачано 6844 вакансий...
# 🔹 Скачано 6944 вакансий...
# 🔹 Скачано 7044 вакансий...
# 🔹 Скачано 7144 вакансий...
# 🔹 Скачано 7244 вакансий...
# 🔹 Скачано 7344 вакансий...
# 🔹 Скачано 7444 вакансий...
# 🔹 Скачано 7544 вакансий...
# 🔹 Скачано 7644 вакансий...
# 🔹 Скачано 7744 вакансий...
# 🔹 Скачано 7844 вакансий...
# 🔹 Скачано 7944 вакансий...
# 🔹 Скачано 8044 вакансий...
# 🔹 Скачано 8144 вакансий...
# 🔹 Скачано 8244 вакансий...
# 🔹 Скачано 8344 вакансий...
# 🔹 Скачано 8444 вакансий...
# 🔹 Скачано 8544 вакансий...
# 🔹 Скачано 8644 вакансий...
# 🔹 Скачано 8744 вакансий...
# 🔹 Скачано 8844 вакансий...
# 🔹 Скачано 8944 вакансий...
# 🔹 Скачано 9044 вакансий...
# 🔹 Скачано 9144 вакансий...
# 🔹 Скачано 9244 вакансий...
# 🔹 Скачано 9344 вакансий...
# 🔹 Скачано 9444 вакансий...
# 🔹 Скачано 9544 вакансий...
# 🔹 Скачано 9644 вакансий...
# 🔹 Скачано 9744 вакансий...
# 🔹 Скачано 9844 вакансий...
# 🔹 Скачано 9944 вакансий...
# 🔹 Скачано 10044 вакансий...
# 🔹 Скачано 10144 вакансий...
# 🔹 Скачано 10244 вакансий...
# 🔹 Скачано 10344 вакансий...
# 🔹 Скачано 10444 вакансий...
# 🔹 Скачано 10544 вакансий...
# 🔹 Скачано 10644 вакансий...
# 🔹 Скачано 10744 вакансий...
# 🔹 Скачано 10844 вакансий...
# 🔹 Скачано 10944 вакансий...
# 🔹 Скачано 11044 вакансий...
# 🔹 Скачано 11144 вакансий...
# 🔹 Скачано 11244 вакансий...
# 🔹 Скачано 11344 вакансий...
# 🔹 Скачано 11444 вакансий...
# 🔹 Скачано 11544 вакансий...
# 🔹 Скачано 11644 вакансий...
# 🔹 Скачано 11744 вакансий...
# 🔹 Скачано 11844 вакансий...
# 🔹 Скачано 11944 вакансий...
# 🔹 Скачано 12044 вакансий...
# 🔹 Скачано 12144 вакансий...
# 🔹 Скачано 12244 вакансий...
# 🔹 Скачано 12344 вакансий...
# 🔹 Скачано 12444 вакансий...
# 🔹 Скачано 12544 вакансий...
# 🔹 Скачано 12644 вакансий...
# 🔹 Скачано 12744 вакансий...
# 🔹 Скачано 12844 вакансий...
# 🔹 Скачано 12944 вакансий...
# 🔹 Скачано 13044 вакансий...
# 🔹 Скачано 13144 вакансий...
# 🔹 Скачано 13244 вакансий...
# 🔹 Скачано 13344 вакансий...
# 🔹 Скачано 13444 вакансий...
# 🔹 Скачано 13544 вакансий...
# 🔹 Скачано 13644 вакансий...
# 🔹 Скачано 13744 вакансий...
# 🔹 Скачано 13844 вакансий...
# 🔹 Скачано 13944 вакансий...
# 🔹 Скачано 14044 вакансий...
# 🔹 Скачано 14144 вакансий...
# 🔹 Скачано 14244 вакансий...
# 🔹 Скачано 14344 вакансий...
# 🔹 Скачано 14444 вакансий...
# 🔹 Скачано 14544 вакансий...
# 🔹 Скачано 14644 вакансий...
# 🔹 Скачано 14744 вакансий...
# 🔹 Скачано 14844 вакансий...
# 🔹 Скачано 14944 вакансий...
# 🔹 Скачано 15044 вакансий...
# 🔹 Скачано 15144 вакансий...
# 🔹 Скачано 15244 вакансий...
# 🔹 Скачано 15344 вакансий...
# 🔹 Скачано 15444 вакансий...
# 🔹 Скачано 15544 вакансий...
# 🔹 Скачано 15644 вакансий...
# 🔹 Скачано 15744 вакансий...
# 🔹 Скачано 15844 вакансий...
# 🔹 Скачано 15944 вакансий...
# 🔹 Скачано 16044 вакансий...
# 🔹 Скачано 16144 вакансий...
# 🔹 Скачано 16244 вакансий...
# 🔹 Скачано 16344 вакансий...
# 🔹 Скачано 16444 вакансий...
# 🔹 Скачано 16544 вакансий...
# 🔹 Скачано 16644 вакансий...
# 🔹 Скачано 16744 вакансий...
# 🔹 Скачано 16844 вакансий...
# 🔹 Скачано 16944 вакансий...
# 🔹 Скачано 17044 вакансий...
# 🔹 Скачано 17144 вакансий...
# 🔹 Скачано 17244 вакансий...
# 🔹 Скачано 17344 вакансий...
# 🔹 Скачано 17444 вакансий...
# 🔹 Скачано 17544 вакансий...
# 🔹 Скачано 17644 вакансий...
# 🔹 Скачано 17744 вакансий...
# 🔹 Скачано 17844 вакансий...
# 🔹 Скачано 17944 вакансий...
# 🔹 Скачано 18044 вакансий...
# 🔹 Скачано 18144 вакансий...
# 🔹 Скачано 18244 вакансий...
# 🔹 Скачано 18344 вакансий...
# 🔹 Скачано 18444 вакансий...
# 🔹 Скачано 18544 вакансий...
# 🔹 Скачано 18644 вакансий...
# 🔹 Скачано 18744 вакансий...
# 🔹 Скачано 18844 вакансий...
# 🔹 Скачано 18944 вакансий...
# 🔹 Скачано 19044 вакансий...
# 🔹 Скачано 19144 вакансий...
# 🔹 Скачано 19244 вакансий...
# 🔹 Скачано 19344 вакансий...
# 🔹 Скачано 19444 вакансий...
# 🔹 Скачано 19544 вакансий...
# 🔹 Скачано 19644 вакансий...
# 🔹 Скачано 19744 вакансий...
# 🔹 Скачано 19844 вакансий...
# 🔹 Скачано 19944 вакансий...
# 🔹 Скачано 20044 вакансий...
# 🔹 Скачано 20144 вакансий...
# 🔹 Скачано 20244 вакансий...
# 🔹 Скачано 20344 вакансий...
# 🔹 Скачано 20444 вакансий...
# 🔹 Скачано 20544 вакансий...
# 🔹 Скачано 20644 вакансий...
# 🔹 Скачано 20744 вакансий...
# 🔹 Скачано 20844 вакансий...
# 🔹 Скачано 20944 вакансий...
# 🔹 Скачано 21044 вакансий...
# 🔹 Скачано 21144 вакансий...
# 🔹 Скачано 21244 вакансий...
# 🔹 Скачано 21344 вакансий...
# 🔹 Скачано 21444 вакансий...
# 🔹 Скачано 21544 вакансий...
# 🔹 Скачано 21547 вакансий...
# 🔹 Скачано 21549 вакансий...
# 🔹 Скачано 21555 вакансий...
# 🔹 Скачано 21559 вакансий...
# 🔹 Скачано 21564 вакансий...
# 🔹 Скачано 21579 вакансий...
# 🔹 Скачано 21679 вакансий...
# 🔹 Скачано 21779 вакансий...
# 🔹 Скачано 21879 вакансий...
# 🔹 Скачано 21979 вакансий...
# 🔹 Скачано 22079 вакансий...
# 🔹 Скачано 22179 вакансий...
# 🔹 Скачано 22279 вакансий...
# 🔹 Скачано 22379 вакансий...
# 🔹 Скачано 22479 вакансий...
# 🔹 Скачано 22579 вакансий...
# 🔹 Скачано 22679 вакансий...
# 🔹 Скачано 22779 вакансий...
# 🔹 Скачано 22879 вакансий...
# 🔹 Скачано 22979 вакансий...
# 🔹 Скачано 23079 вакансий...
# 🔹 Скачано 23179 вакансий...
# 🔹 Скачано 23279 вакансий...
# 🔹 Скачано 23379 вакансий...
# 🔹 Скачано 23479 вакансий...
# 🔹 Скачано 23579 вакансий...
# 🔹 Скачано 23679 вакансий...
# 🔹 Скачано 23779 вакансий...
# 🔹 Скачано 23879 вакансий...
# 🔹 Скачано 23979 вакансий...
# 🔹 Скачано 24079 вакансий...
# 🔹 Скачано 24179 вакансий...
# 🔹 Скачано 24279 вакансий...
# 🔹 Скачано 24379 вакансий...
# 🔹 Скачано 24479 вакансий...
# 🔹 Скачано 24579 вакансий...
# 🔹 Скачано 24679 вакансий...
# 🔹 Скачано 24779 вакансий...
# 🔹 Скачано 24879 вакансий...
# 🔹 Скачано 24979 вакансий...
# 🔹 Скачано 25079 вакансий...
# 🔹 Скачано 25179 вакансий...
# 🔹 Скачано 25279 вакансий...
# 🔹 Скачано 25379 вакансий...
# 🔹 Скачано 25479 вакансий...
# 🔹 Скачано 25579 вакансий...
# 🔹 Скачано 25679 вакансий...
# 🔹 Скачано 25779 вакансий...
# 🔹 Скачано 25879 вакансий...
# 🔹 Скачано 25979 вакансий...
# 🔹 Скачано 26079 вакансий...
# 🔹 Скачано 26179 вакансий...
# 🔹 Скачано 26279 вакансий...
# 🔹 Скачано 26379 вакансий...
# 🔹 Скачано 26479 вакансий...
# 🔹 Скачано 26579 вакансий...
# 🔹 Скачано 26679 вакансий...
# 🔹 Скачано 26779 вакансий...
# 🔹 Скачано 26879 вакансий...
# 🔹 Скачано 26979 вакансий...
# 🔹 Скачано 27079 вакансий...
# 🔹 Скачано 27179 вакансий...
# 🔹 Скачано 27279 вакансий...
# 🔹 Скачано 27379 вакансий...
# 🔹 Скачано 27479 вакансий...
# 🔹 Скачано 27579 вакансий...
# 🔹 Скачано 27679 вакансий...
# 🔹 Скачано 27779 вакансий...
# 🔹 Скачано 27879 вакансий...
# 🔹 Скачано 27979 вакансий...
# 🔹 Скачано 28079 вакансий...
# 🔹 Скачано 28179 вакансий...
# 🔹 Скачано 28279 вакансий...
# 🔹 Скачано 28379 вакансий...
# 🔹 Скачано 28479 вакансий...
# 🔹 Скачано 28579 вакансий...
# 🔹 Скачано 28679 вакансий...
# 🔹 Скачано 28779 вакансий...
# 🔹 Скачано 28879 вакансий...
# 🔹 Скачано 28979 вакансий...
# 🔹 Скачано 29079 вакансий...
# 🔹 Скачано 29179 вакансий...
# 🔹 Скачано 29279 вакансий...
# 🔹 Скачано 29379 вакансий...
# 🔹 Скачано 29479 вакансий...
# 🔹 Скачано 29579 вакансий...
# 🔹 Скачано 29679 вакансий...
# 🔹 Скачано 29779 вакансий...
# 🔹 Скачано 29879 вакансий...
# 🔹 Скачано 29979 вакансий...
# 🔹 Скачано 30079 вакансий...
# 🔹 Скачано 30179 вакансий...
# 🔹 Скачано 30279 вакансий...
# 🔹 Скачано 30379 вакансий...
# 🔹 Скачано 30479 вакансий...
# 🔹 Скачано 30579 вакансий...
# 🔹 Скачано 30679 вакансий...
# 🔹 Скачано 30779 вакансий...
# 🔹 Скачано 30879 вакансий...
# 🔹 Скачано 30979 вакансий...
# 🔹 Скачано 31079 вакансий...
# 🔹 Скачано 31179 вакансий...
# 🔹 Скачано 31279 вакансий...
# 🔹 Скачано 31379 вакансий...
# 🔹 Скачано 31479 вакансий...
# 🔹 Скачано 31579 вакансий...
# 🔹 Скачано 31679 вакансий...
# 🔹 Скачано 31779 вакансий...
# 🔹 Скачано 31879 вакансий...
# 🔹 Скачано 31979 вакансий...
# 🔹 Скачано 32079 вакансий...
# 🔹 Скачано 32179 вакансий...
# 🔹 Скачано 32279 вакансий...
# 🔹 Скачано 32379 вакансий...
# 🔹 Скачано 32479 вакансий...
# 🔹 Скачано 32579 вакансий...
# 🔹 Скачано 32679 вакансий...
# 🔹 Скачано 32779 вакансий...
# 🔹 Скачано 32879 вакансий...
# 🔹 Скачано 32979 вакансий...
# 🔹 Скачано 33079 вакансий...
# 🔹 Скачано 33179 вакансий...
# 🔹 Скачано 33279 вакансий...
# 🔹 Скачано 33379 вакансий...
# 🔹 Скачано 33479 вакансий...
# 🔹 Скачано 33579 вакансий...
# ✅ Вакансии сохранены в hh_vacancies_Zaibal_MAIN.csv (33579 шт.)
